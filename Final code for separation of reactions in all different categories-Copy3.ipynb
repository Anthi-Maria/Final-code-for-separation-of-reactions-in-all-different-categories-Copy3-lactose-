# %%
import numpy as np
import pandas as pd
import cobra.test
import os

from os.path import join

from time import time


from cobra.flux_analysis import (
    single_gene_deletion, single_reaction_deletion, double_gene_deletion,
    double_reaction_deletion)

a = cobra.io.read_sbml_model("iEC1344_C.xml")
# Out:
# Academic license - for non-commercial use only - expires 2023-02-21
# Using license file /home/schwartzlab/gurobi.lic

# %%
csvFile = pd.read_csv('biomass_per_flux_for_reaction_ALAALAD.csv') #this is flat and then decreasing i.e. saturating
i=0
l= list()

while i < 201:
    inf= csvFile.iloc[i,  2]
    flt= float(csvFile.iloc[i,  2])
    
    if csvFile.iloc[i,  2] == flt:
        l.append(csvFile.iloc[i,  2])
    i= i+1

csvFile2= pd.DataFrame (l, columns = ['Biomass'])
csvFile2

my_series = csvFile2['Biomass'].squeeze()
type(my_series)

my_series

if my_series.is_monotonic_decreasing == False and my_series.is_monotonic == False:
    print("This reaction is both increasting and decreasing.")
# Out:
# This reaction is both increasting and decreasing.

# %%
int_reactions= list()
i= -1
r = a.reactions[0]
r_id = r.id
zero= list()
one= list()

for r in a.reactions:
    i= i+1
    r = a.reactions[i]
    r_id = r.id

    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_lactose.csv'.format(r_id))
    v= len(csvFile["Biomass"])-csvFile["Biomass"].isna().sum()
    
    if v == 1:
        one.append(r_id)
    elif v == 0:
        zero.append(r_id)

print(one)
print(zero)

D= pd.DataFrame (one, columns = ['1 feasible value'])
D
# Out:
# ['EX_cm_e', 'EX_cobalt2_e', 'EX_colipa_e', 'EX_colipap_e', 'EX_crn_e', 'EX_crn__D_e', 'DM_4crsol_c', 'EX_cu2_e', 'DM_5drib_c', 'EX_cyan_e', 'DM_aacald_c', 'DM_amob_c', 'DM_mththf_c', 'EX_glyb_e', 'EX_gthox_e', 'BIOMASS_Ec_iJO1366_WT_53p95M', 'BIOMASS_Ec_iJO1366_core_53p95M', 'EX_14glucan_e', 'EX_h2o2_e', 'EX_hacolipa_e', 'EX_halipa_e', 'EX_34dhpac_e', 'EX_hg2_e', 'EX_4hoxpacd_e', 'EX_5mtr_e', 'EX_cys__D_e', 'EX_acgal_e', 'EX_inost_e', 'EX_k_e', 'EX_kdo2lipid4_e', 'EX_acolipa_e', 'EX_adocbl_e', 'EX_lipa_e', 'EX_lipa_cold_e', 'EX_ag_e', 'EX_lipoate_e', 'EX_ala_B_e', 'EX_malthx_e', 'EX_maltpt_e', 'EX_malttr_e', 'EX_maltttr_e', 'EX_arbt_e', 'EX_meoh_e', 'EX_met__D_e', 'EX_aso3_e', 'EX_met__L_e', 'EX_metsox_R__L_e', 'EX_metsox_S__L_e', 'EX_mg2_e', 'EX_mincyc_e', 'EX_btn_e', 'EX_mmet_e', 'EX_mn2_e', 'EX_ca2_e', 'EX_cbi_e', 'EX_mobd_e', 'EX_n2o_e', 'EX_na1_e', 'EX_nac_e', 'EX_cbl1_e', 'EX_cd2_e', 'EX_chol_e', 'EX_cl_e', 'EX_ni2_e', 'EX_nmn_e', 'EX_dms_e', 'EX_novbcn_e', 'EX_o16a4colipa_e', 'EX_doxrbcn_e', 'EX_o2s_e', 'EX_xtsn_e', 'EX_pacald_e', 'EX_zn2_e', '12DGR120tipp', '12DGR140tipp', '12DGR141tipp', '12DGR160tipp', 'EX_pheme_e', 'EX_pnto__R_e', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', '14GLUCANtexi', 'EX_eca4colipa_e', '23CAMPtex', '23CCMPtex', 'EX_pydam_e', '23CGMPtex', '23CUMPtex', '23DAPPAt2pp', '23DAPPAtex', '23PDE2pp', '23PDE4pp', 'EX_pydx_e', 'EX_pydxn_e', 'EX_rfamp_e', '23PDE7pp', '23PDE9pp', 'EX_enlipa_e', 'EX_sel_e', '26DAHtex', 'EX_slnt_e', 'EX_so2_e', 'EX_so3_e', 'EX_tcynt_e', 'EX_thm_e', 'EX_tma_e', 'EX_tsul_e', 'EX_ttrcyc_e', 'EX_tungs_e', '34dhpactex', '3GMPtex', '3AMPtex', '3CMPtex', 'EX_fuc__L_e', '3HCINNMH', 'AADDGT', 'AAMYLpp', '3HPPPNH', '3KGK', 'AB6PGH', '3NTD2pp', '3NTD4pp', '3NTD7pp', 'EX_fusa_e', '3NTD9pp', 'ACACt2pp', 'ACACtex', 'ACANTHAT', 'ACBIPGT', 'ACGAL1PPpp', 'ACGAL1Ptex', 'ACGALtex', 'ACGAM1PPpp', 'ACGAM1Ptex', 'ACGAMT', '3PEPTtex', '3UMPtex', '42A12BOOXpp', 'ACGAtex', '4HOXPACDtex', '4HTHRS', 'ACMAMUT', '4PEPTtex', 'ACMANAtex', 'ACMUMptspp', 'ACMUMtex', 'ACNAMt2pp', '5DOAN', '5MTRtex', '5MTRtpp', 'A5PISO', 'ACNAMtex', 'ACNML', 'ACONIs', 'ACONMT', 'AGt3', 'AHCYSNS', 'ACPS1', 'ADCL', 'ADCS', 'ALATRS', 'ALDD4', 'ADNtex', 'EX_gbbtn_e', 'ADOCBIK', 'ADOCBLS', 'ADOCBLabcpp', 'ADOCBLtonex', 'ALLK', 'ALLPI', 'ALLULPE', 'ALLabcpp', 'EX_gdp_e', 'ALLtex', 'ALTRH', 'AMALT1', 'AMANAPEr', 'AMANK', 'AGMHE', 'AMAOTr', 'AMMQLT8', 'AMPMS2', 'AMPTASEPG', 'AMPtex', 'AOXSr2', 'ANHGMtex', 'AP5AH', 'ASPTRS', 'APCS', 'ASR', 'CDGR', 'CDGS', 'CDPMEK', 'CFAS160E', 'CFAS160G', 'CFAS180E', 'BALAtex', 'CFAS180G', 'CHLtex', 'BMOCOS', 'BMOGDS1', 'BMOGDS2', 'CHOLD', 'BTNt2ipp', 'BTNtex', 'BTS5', 'CHRPL', 'CHTBSptspp', 'CHTBStex', 'BUTSO3abcpp', 'CINNDO', 'BUTSO3tex', 'BUTt2rpp', 'BUTtex', 'BWCOGDS1', 'BWCOGDS2', 'BWCOS', 'CA2tex', 'CBIAT', 'CBItonex', 'CBIuabcpp', 'CBL1abcpp', 'CBL1tonex', 'CBLAT', 'CLt3_2pp', 'CLtex', 'CMPtex', 'CCGS', 'CD2tex', 'COBALT2tex', 'APPLDHr', 'COLIPAKpp', 'COLIPAPabctex', 'COLIPAabcpp', 'APRAUR', 'CPMPS', 'CPPPGO2', 'CRNBTCT', 'CRNCAR', 'CRNCBCT', 'ARAI', 'CRNCDH', 'CRNDCAL2', 'CPH4S', 'CRNDtex', 'CRNt7pp', 'CRNtex', 'DADNtex', 'CSNtex', 'DAMPtex', 'DAPAL', 'CU2tex', 'DB4PS', 'DBTS', 'CUtex', 'CYANST', 'CYANSTpp', 'CYANtex', 'CYNTAH', 'CYNTt2pp', 'DC6PH', 'DCAtex', 'DCMPtex', 'CYNTtex', 'DCYTtex', 'DDCAtexi', 'DDGALK', 'CYSDabcpp', 'CYSDtex', 'CYSSADS', 'DDGLCNt2rpp', 'DDGLCNtex', 'CYSTL', 'CYSTRS', 'DDPGALA', 'DGMPtex', 'DGSNtex', 'ARBTptspp', 'CYTDtex', 'ARBTtex', 'DHCIND', 'DHCINDO', 'DHFS', 'DHMPTR', 'DHNAOT4', 'DHNCOAS', 'DHNCOAT', 'DIMPtex', 'DINStex', 'DKGLCNR1', 'DHNPTE', 'DMATT', 'DHPPD', 'DMQMT', 'DHPPDA2', 'ARBtex', 'DHPS2', 'DHPTDCs2', 'DHPTDNR', 'DMSOtex', 'DMSOtpp', 'DMStex', 'DNMPPA', 'DNTPPA', 'DHPTDNRN', 'DHPTPE', 'DOPAtex', 'DPCOAK', 'DPR', 'ECAP1pp', 'ECAP2pp', 'ECAP3pp', 'ECAtpp', 'DSBCGT', 'DSBDR', 'DSERtex', 'DTARTD', 'DTMPtex', 'DUMPtex', 'DURItex', 'EDTXS1', 'EDTXS2', 'EDTXS3', 'EDTXS4', 'EGMEACPR', 'ARGTRS', 'DXPRIi', 'DXPS', 'DXYLK', 'E4PD', 'EPMEACPR', 'ETHSO3abcpp', 'E ...
# []
#     1 feasible value
# 0            EX_cm_e
# 1       EX_cobalt2_e
# 2        EX_colipa_e
# 3       EX_colipap_e
# 4           EX_crn_e
# ..               ...
# 962            AMID3
# 963             SUCP
# 964          LTARTDH
# 965           UAG4Ei
# 966          UGCIAMH
#
# [967 rows x 1 columns]

# %%
i= 0
diff_saturated= list()
diff_indecr= list()
flat= list()
r = a.reactions[0]


for r in a.reactions:
    
    l= list()
    n=0
    n2=0
    count=0
    r = a.reactions[i]
    r_id = r.id
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_lactose.csv'.format(r_id))

    while n < 201:
        inf= csvFile.iloc[n,  2]
        flt= float(csvFile.iloc[n,  2])
    
        if csvFile.iloc[n,  2] == flt:
            l.append(csvFile.iloc[n,  2])
        n= n+1

    d= pd.DataFrame (l, columns = ['Biomass'])


    if len(d)> 1:
        
        while n2 < len(d):

            if d.iloc[n2,  0] > max(d["Biomass"])-0.02 and d.iloc[n2,  0] < max(d["Biomass"])+0.02:
                count= count+1
    
            n2= n2+1
        
        if count> 0.8*len(d) and count< 0.95*len(d):
            diff_saturated.append(r_id)

        elif count> 0.95*len(d):
            flat.append(r_id)
        
        else:
            diff_indecr.append(r_id)

    
    i= i+1

flat
diff_indecr
diff_saturated
# Out:
# ['EX_h_e',
#  'EX_lys__L_e',
#  'EX_minohp_e',
#  'EX_ppt_e',
#  'EX_fe2_e',
#  'EX_fe3_e',
#  'ACACT5r',
#  'ACACT6r',
#  'ACACT7r',
#  'ACACT8r_copy1',
#  'ADA',
#  'ADD',
#  'DADA',
#  'CTECOAI7_copy1',
#  'CTECOAI8_copy1',
#  'DHAPT',
#  'DAAD',
#  'EAR120y',
#  'EAR140y',
#  'EAR160y',
#  'EAR161y',
#  'EAR180y',
#  'EAR181y',
#  'FADRx2',
#  'FDH4pp',
#  'ASNS1',
#  'FEROpp',
#  'FE2tex',
#  'FLVR',
#  'FMNRx2',
#  'FE3tex',
#  'GLUt2rpp',
#  'GLYCK',
#  'GLYCK2',
#  'GLYCLTDy',
#  'Htex',
#  'HACD5',
#  'HACD6',
#  'HACD7',
#  'HACD8',
#  'GLYCTO2',
#  'GLYOX3',
#  'L_LACD2_copy1',
#  'L_LACD3_copy1',
#  'MMM',
#  'MICITDr_copy1',
#  'NTD8',
#  'NTPTP1',
#  'GTPDPDP',
#  'NTRIR4pp',
#  'SSALx',
#  'SUCOAS',
#  'SERD_D',
#  'SERD_L',
#  'THRA',
#  'THRD',
#  'TRPS2',
#  'TRSARr',
#  'XTSNH_copy1',
#  'L_LACD3_copy2',
#  'MMM2',
#  'L_LACD2_copy2',
#  'XTSNH_copy2']

# %%
i= 0
r_id= diff_saturated[i]
diff_saturatedFINAL= list()
Ushaped_reactions= list()

for r_id in diff_saturated:

    l= list()
    n=0
    n2=0
    r_id = diff_saturated[i]
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_lactose.csv'.format(r_id))

    while n < 201:
        inf= csvFile.iloc[n,  2]
        flt= float(csvFile.iloc[n,  2])
    
        if csvFile.iloc[n,  2] == flt:
            l.append(csvFile.iloc[n,  2])
        n= n+1

    d= pd.DataFrame (l, columns = ['Biomass'])
    
    if d.iloc[0,0] > d.iloc[1,0]-0.02 and d.iloc[0,0] < d.iloc[1,0]+0.02 or\
       d.iloc[1,0] > d.iloc[0,0]-0.02 and d.iloc[1,0] < d.iloc[0,0]+0.02 or\
       d.iloc[len(d)-2,0] > d.iloc[len(d)-1,0]-0.02 and d.iloc[len(d)-2,0] < d.iloc[len(d)-1,0]+0.02 or\
       d.iloc[len(d)-1,0] > d.iloc[len(d)-2,0]-0.02 and d.iloc[len(d)-1,0] < d.iloc[len(d)-2, 0]+0.02:
        diff_saturatedFINAL.append(r_id)
    
    else:
        Ushaped_reactions.append(r_id)
    
    i= i+1

diff_saturatedFINAL
Ushaped_reactions
# Out:
# ['EX_h_e',
#  'EX_lys__L_e',
#  'EX_fe3_e',
#  'DHAPT',
#  'ASNS1',
#  'FEROpp',
#  'GLYCK2',
#  'Htex',
#  'NTD8',
#  'GTPDPDP',
#  'NTRIR4pp']

# %%
i2= 0
r_id = diff_indecr[0]
mon_incr= list()
mon_decr= list()
one_feasible_value= list()

for r_id in diff_indecr:                    #this code finds reactions that are either stable or constantly decrease
    
    i=0
    r_id = diff_indecr[i2]
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_lactose.csv'.format(r_id))
    l= list()

    while i < 201:
        inf= csvFile.iloc[i,  2]
        flt= float(csvFile.iloc[i,  2])
    
        if csvFile.iloc[i,  2] == flt:
            l.append(csvFile.iloc[i,  2])
        i= i+1

    csvFile2= pd.DataFrame (l, columns = ['Biomass'])
    csvFile2.Biomass = csvFile2.Biomass.round(2)

    my_series = csvFile2['Biomass'].squeeze()
    type(my_series)

    if len(csvFile2['Biomass'])>1:
        
        if my_series.is_monotonic_decreasing ==True:
            mon_decr.append(r_id)
        elif my_series.is_monotonic ==True:
            mon_incr.append(r_id)

    
    i2= i2 + 1

mon_decr
# Out:
# ['EX_cmp_e',
#  'EX_csn_e',
#  'EX_glcn_e',
#  'EX_glcur_e',
#  'EX_glcur1p_e',
#  'EX_gln__L_e',
#  'EX_glu__L_e',
#  'DM_oxam_c',
#  'EX_gly_e',
#  'EX_glyald_e',
#  'EX_glyc2p_e',
#  'EX_glyc3p_e',
#  'EX_glyclt_e',
#  'EX_gmp_e',
#  'EX_gsn_e',
#  'EX_12ppd__R_e',
#  'EX_15dap_e',
#  'EX_23camp_e',
#  'EX_23cgmp_e',
#  'EX_23cump_e',
#  'EX_2ddglcn_e',
#  'EX_h2s_e',
#  'EX_3amp_e',
#  'EX_3cmp_e',
#  'EX_3gmp_e',
#  'EX_3hpp_e',
#  'EX_3ump_e',
#  'EX_his__L_e',
#  'EX_hom__L_e',
#  'EX_hxan_e',
#  'EX_5dglcn_e',
#  'EX_cys__L_e',
#  'EX_cytd_e',
#  'EX_ile__L_e',
#  'EX_dad_2_e',
#  'EX_imp_e',
#  'EX_acac_e',
#  'EX_acald_e',
#  'EX_damp_e',
#  'EX_ins_e',
#  'EX_acgam1p_e',
#  'EX_lac__D_e',
#  'EX_lac__L_e',
#  'EX_acser_e',
#  'EX_adn_e',
#  'EX_leu__L_e',
#  'EX_dcmp_e',
#  'EX_dcyt_e',
#  'EX_akg_e',
#  'EX_mal__D_e',
#  'EX_ala__L_e',
#  'EX_mal__L_e',
#  'EX_alaala_e',
#  'EX_dgmp_e',
#  'EX_man6p_e',
#  'EX_amp_e',
#  'EX_arg__L_e',
#  'EX_dgsn_e',
#  'EX_asp__L_e',
#  'EX_dha_e',
#  'EX_dimp_e',
#  'EX_din_e',
#  'EX_cit_e',
#  'EX_dtmp_e',
#  'EX_orn_e',
#  'EX_dump_e',
#  'EX_phe__L_e',
#  'EX_duri_e',
#  'EX_psclys_e',
#  'EX_pser__L_e',
#  'EX_pyr_e',
#  'EX_r5p_e',
#  'EX_rmn_e',
#  'EX_ser__D_e',
#  '2AGPA120tipp',
#  '2AGPA140tipp',
#  '2AGPA141tipp',
#  'EX_ser__L_e',
#  '2AGPA160tipp',
#  '2AGPA161tipp',
#  'EX_etha_e',
#  '2AGPA180tipp',
#  '2AGPA181tipp',
#  '2AGPE120tipp',
#  '2AGPE140tipp',
#  '2AGPE141tipp',
#  'EX_spmd_e',
#  'EX_f6p_e',
#  '2AGPE160tipp',
#  '2AGPE161tipp',
#  '2AGPE180tipp',
#  '2AGPE181tipp',
#  'EX_thr__L_e',
#  'EX_fald_e',
#  'EX_thrp_e',
#  'EX_thym_e',
#  'EX_thymd_e',
#  'EX_trp__L_e',
#  '2AGPG120tipp',
#  '2AGPG140tipp',
#  '2AGPG141tipp',
#  '2AGPG160tipp',
#  '2AGPG161tipp',
#  '2AGPG180tipp',
#  '2AGPG181tipp',
#  'EX_tyr__L_e',
#  'EX_ump_e',
#  'EX_urea_e',
#  'EX_uri_e',
#  '2MAHMP',
#  '3HAD100',
#  '3AMACHYD',
#  '3HAD120',
#  '3HAD121',
#  '3HAD140',
#  'EX_frulys_e',
#  '3HAD141',
#  'EX_fruur_e',
#  '3HAD160',
#  '3HAD161',
#  'AACPS8',
#  '3HAD180',
#  '3HAD181',
#  '3HAD40',
#  '3HAD60',
#  '3HAD80',
#  'AACPS9',
#  'AACTOOR',
#  '3HPPtpp',
#  'ABTA',
#  'ABUTD',
#  '3OAR100',
#  '3OAR120',
#  '3OAR121',
#  'EX_g3pc_e',
#  '3OAR141',
#  '3OAR160',
#  '3OAR161',
#  '3OAR180',
#  '3OAR181',
#  '3OAR40',
#  '3OAR60',
#  '3OAR80',
#  '3OAS100',
#  '3OAS120',
#  '3OAS121',
#  'EX_g3pe_e',
#  '3OAS141',
#  '3OAS160',
#  '3OAS161',
#  'EX_g3pg_e',
#  '3OAS180',
#  '3OAS181',
#  '3OAS60',
#  'ACGAMK',
#  '3OAS80',
#  '3PEPTabcpp',
#  'EX_g3pi_e',
#  'ACM6PH',
#  'EX_g3ps_e',
#  'EX_g6p_e',
#  'ACOAD3f',
#  'EX_gal_bD_e',
#  'ACOAD4f',
#  'ACOAD5f',
#  'EX_gal1p_e',
#  'ACOAD6f',
#  'ACOAD7f',
#  'ACOAD8f',
#  'ACOLIPAabctex',
#  'ACPPAT120',
#  'ACPPAT140',
#  'ACPPAT141',
#  'AGPAT181',
#  'ACPPAT180',
#  'ACPPAT181',
#  'ALAALAD',
#  'ACSERtpp',
#  'ALAGLUE',
#  'ALATA_D2',
#  'ALAabcpp',
#  'ADMDC',
#  'ALDD2x',
#  'ADNCYC',
#  'EX_gam6p_e',
#  'ADNUC',
#  'ALDD2y',
#  'ADPRDP',
#  'ADPT',
#  'ALLTAMH',
#  'ALLTN',
#  'AGDC',
#  'AGM4PApp',
#  'ALR2',
#  'ALR4x',
#  'AM3PA',
#  'AGM4PH',
#  'AGM4Pt2pp',
#  'AGMH',
#  'AGMT',
#  'AGMt2pp',
#  'AMPN',
#  'AGPAT120',
#  'AGPAT140',
#  'AOBUTDs',
#  'AGPAT141',
#  'AMPTASECG',
#  'ANHMK',
#  'AGPAT180',
#  'AP4AH',
#  'AP4AS',
#  'ASPabcpp',
#  'APG3PAT120',
#  'ASPt2_2pp',
#  'ASPt2_3pp',
#  'APG3PAT140',
#  'ASPt2pp_copy2',
#  'APG3PAT141',
#  'AST',
#  'ATPHs',
#  'ATPM',
#  'APG3PAT180',
#  'CGLYabcpp',
#  'CHLabcpp',
#  'APG3PAT181',
#  'CITt3pp',
#  'CLIPAabctex',
#  'CADVtpp',
#  'CLPNS120pp',
#  'CLPNS140pp',
#  'CLPNS141pp',
#  'CLPNS160pp',
#  'CLPNS161pp',
#  'CLPNS180pp',
#  'CLPNS181pp',
#  'CBMD',
#  'CD2abcpp',
#  'CMtex',
#  'CMtpp',
#  'CD2tpp',
#  'COBALT2abcpp',
#  'COLIPAabctex',
#  'CPGNUtex',
#  'CPGNUtpp',
#  'CPGNabcpp',
#  'CPGNexs',
#  'CRNDabcpp',
#  'CPGNtonex',
#  'CRNabcpp',
#  'CSND',
#  'CTBTabcpp',
#  'DASYN120',
#  'ARBTNabcpp',
#  'CU1abcpp',
#  'DASYN140',
#  'DASYN141',
#  'CU2abcpp',
#  'ARBTNexs',
#  'DASYN180',
#  'DASYN181',
#  'DATPHs',
#  'ARBTNtex',
#  'DCYTD',
#  'ARBTNtonex',
#  'ARBTNtpp',
#  'CYSabc2pp',
#  'CYTBD2pp',
#  'CYTBDpp',
#  'DHBD',
#  'DHBS',
#  'DHBSH',
#  'ARBabcpp',
#  'ARBt3ipp',
#  'DOXRBCNtex',
#  'DOXRBCNtpp',
#  'DRPA',
#  'ECA4COLIPAabctex',
#  'ARGORNt7pp',
#  'EDA',
#  'EDD',
#  'DURADx',
#  'DUTPDP',
#  'ENLIPAabctex',
#  'ENTCS',
#  'ARGabcpp',
#  'ETHAAL',
#  'ARGt3pp',
#  'F6PP',
#  'FA120ACPHi',
#  'FA140ACPHi',
#  'FA141ACPHi',
#  'FA160ACPHi',
#  'FA161ACPHi',
#  'FACOAE60',
#  'FACOAL120t2pp',
#  'FACOAL140t2pp',
#  'FBA3',
#  'FACOAL141t2pp',
#  'FACOAL160t2pp',
#  'FACOAL161t2pp',
#  'FACOAL180t2pp',
#  'FACOAL181t2pp',
#  'FACOAL60t2pp',
#  'ASNNpp',
#  'FEOXAMtonex',
#  'FESD1s',
#  'FE2abcpp',
#  'FE2t2pp',
#  'FE2t3pp',
#  'FESR',
#  'FHL',
#  'FE3HOXUtex',
#  'FE3HOXUtpp',
#  'FE3HOXabcpp',
#  'ASNabcpp',
#  'FE3HOXexs',
#  'FE3HOXtonex',
#  'FORtppi',
#  'FE3Ri',
#  'FRD3',
#  'FECRMUtex',
#  'FECRMUtpp',
#  'FECRMabcpp',
#  'FECRMexs',
#  'FECRMtonex',
#  'FEENTERabcpp',
#  'FEENTERexs',
#  'FTHFLi',
#  'FEENTERtex',
#  'FUMt2_3pp',
#  'FEENTERtonex',
#  'FEENTERtpp',
#  'FUSAtex',
#  'FEOXAMUtex',
#  'FUSAtpp',
#  'FEOXAMUtpp',
#  'FEOXAMabcpp',
#  'FEOXAMexs',
#  'G3PD5',
#  'G3PD6',
#  'G3PD7',
#  'G5SD',
#  'GLCDpp',
#  'ASPO3',
#  'GLCNt2rpp',
#  'G6PP',
#  'ASPO4',
#  'ASPO5',
#  'GLCabcpp',
#  'ASPT',
#  'GALUi',
#  'GALabcpp',
#  'GLU5K',
#  'GLUCYS',
#  'GLUN',
#  'GDPMNP',
#  'GLUabcpp',
#  'GLXCL',
#  'GGGABADr',
#  'GGGABAH',
#  'GGPTRCO',
#  'GGPTRCS',
#  'GLYBabcpp',
#  'GUAt2pp',
#  'GLYC3Pabcpp',
#  'H2St1pp',
#  'HXPRT',
#  'HYPOE',
#  'ICHORT',
#  'IDOND2',
#  'HEX1',
#  'HEX4',
#  'ILETA',
#  'HG2abcpp',
#  'ILEabcpp',
#  'HISabcpp',
#  'INSH',
#  'HOMt2pp',
#  'GLYOX',
#  'IPPMIa',
#  'IPPMIb',
#  'HPYRRy',
#  'LPLIPAL1E181pp',
#  'LPLIPAL1G120pp',
#  'Kt3pp',
#  'LPLIPAL1G140pp',
#  'LPLIPAL1G141pp',
#  'LPLIPAL1G160pp',
#  'LPLIPAL1G161pp',
#  'LPLIPAL1G180pp',
#  'LPLIPAL1G181pp',
#  'LPLIPAL2A120',
#  'LPLIPAL2A140',
#  'LPLIPAL2A141',
#  'LPLIPAL2A160',
#  'LPLIPAL2A161',
#  'LPLIPAL2A180',
#  'LPLIPAL2A181',
#  'LADGMDH',
#  'LALDO3',
#  'LALGP',
#  'LCADi',
#  'LCARR',
#  'LCARS',
#  'LCTSt3ipp',
#  'LCTStpp',
#  'LDH_D2',
#  'LEUabcpp',
#  'LGTHL',
#  'LIPAabctex',
#  'LPLIPAL1A120pp',
#  'LSERDHr',
#  'LYSDC',
#  'LPLIPAL1A140pp',
#  'LPLIPAL1A141pp',
#  'LPLIPAL1A160pp',
#  'LYSabcpp',
#  'LPLIPAL1A161pp',
#  'LYSt3pp',
#  'LPLIPAL1A180pp',
#  'LPLIPAL1A181pp',
#  'LPLIPAL1E120pp',
#  'LPLIPAL1E140pp',
#  'LPLIPAL1E141pp',
#  'LPLIPAL1E160pp',
#  'LPLIPAL1E161pp',
#  'LPLIPAL1E180pp',
#  'MCITD',
#  'MCITL2',
#  'MCITS',
#  'MALt2_3pp',
#  'MALt3pp',
#  'MAN1PT2',
#  'MCTP1Bpp',
#  'MCTP2App',
#  'MDDCP2pp',
#  'MDDCP4pp',
#  'MDDCP5pp',
#  'MDDEP1pp',
#  'MDDEP2pp',
#  'MDDEP4pp',
#  'MINCYCtex',
#  'MINCYCtpp',
#  'MDH2',
#  'MLDCP1App',
#  'MDH3',
#  'GPDDA2',
#  'ME1',
#  'MLDCP3App',
#  'MLDEP1pp',
#  'MELIBt2pp',
#  'MELIBt3ipp',
#  'MLTG3',
#  'GPDDA2pp',
#  'MLTG4',
#  'MLTG5',
#  'METOX1s',
#  'MLTGY3pp',
#  'MLTGY4pp',
#  'METOX2s',
#  'MMCD',
#  'METSOXR1',
#  'METSOXR2',
#  'MN2t3pp',
#  'GPDDA4',
#  'MN6PP',
#  'MG2tpp',
#  'MG2uabcpp',
#  'MPTG2',
#  'NADDP',
#  'NADH10',
#  'MSAR',
#  'GRXR',
#  'MTAN',
#  'NADH5',
#  'NADH9',
#  'NADN',
#  'NADPHQR2',
#  'NADPHQR3',
#  'NADPHQR4',
#  'NADPPPS',
#  'NADTRHD',
#  'NAMNPP',
#  'NAt3_1p5pp',
#  'NAt3_2pp',
#  'GSPMDA',
#  'GSPMDS',
#  'NDPK6',
#  'NOVBCNtex',
#  'NOVBCNtpp',
#  'NTD10',
#  'NI2abcpp',
#  'GTHOr',
#  'NTD12',
#  'GTHPi',
#  'GTHRDHpp',
#  'NTD3',
#  'NTD4',
#  'NTD5',
#  'NNAM',
#  'GTHRDabc2pp',
#  'NTD7',
#  'NO3R2bpp',
#  'NTP1',
#  'NTP10',
#  'NTP3',
#  'NTP5',
#  'NTPP1',
#  'NTPP10',
#  'NTPP11',
#  'GTHS',
#  'NTPP2',
#  'NTPP3',
#  'NTPP4',
#  'NTPP5',
#  'NTPP6',
#  'NTPP7',
#  'NTPP8',
#  'NTPP9',
#  'NTPTP2',
#  'ORNabcpp',
#  'GTPDPK',
#  'GTPHs',
#  'OXAMTC',
#  'OAADC',
#  'PFK',
#  'GUACYC',
#  'PG120abcpp',
#  'PG140abcpp',
#  'PG141abcpp',
#  'PG160abcpp',
#  'PG161abcpp',
#  'PG180abcpp',
#  'PG181abcpp',
#  'GUAPRT',
#  'PLIPA1A180pp',
#  'PDE1',
#  'PDE4',
#  'PGP120abcpp',
#  'PGP140abcpp',
#  'PGP141abcpp',
#  'PGP160abcpp',
#  'PGP161abcpp',
#  'PGP180abcpp',
#  'PDXPP',
#  'PGP181abcpp',
#  'PE120abcpp',
#  'PLIPA1A181pp',
#  'PE140abcpp',
#  'PE141abcpp',
#  'PE180abcpp',
#  'PGPP120pp',
#  'PGPP140pp',
#  'PGPP141pp',
#  'PGPP160pp',
#  'PE181abcpp',
#  'PLIPA1E120pp',
#  'PGPP161pp',
#  'PGPP180pp',
#  'PGPP181pp',
#  'PLIPA1E140pp',
#  'PGSA120',
#  'PGSA140',
#  'PLIPA1E141pp',
#  'PGSA141',
#  'PGSA160',
#  'PGSA161',
#  'PGSA180',
#  'PGSA181',
#  'PHETA1',
#  'PLIPA1E160pp',
#  'PROabcpp',
#  'PLIPA1E161pp',
#  'PLIPA1A120pp',
#  'PLIPA1A140pp',
#  'PSD120',
#  'PLIPA1E180pp',
#  'PSD140',
#  'PSD141',
#  'PLIPA1A141pp',
#  'PLIPA1A160pp',
#  'PLIPA1A161pp',
#  'PSD180',
#  'PLIPA1E181pp',
#  'PSD181',
#  'PLIPA1G120pp',
#  'PSSA120',
#  'PSSA140',
#  'PSSA141',
#  'PLIPA1G140pp',
#  'PLIPA1G141pp',
#  'R5PP',
#  'PSSA180',
#  'PSSA181',
#  'RBK',
#  'RFAMPtex',
#  'PTRCTA',
#  'PLIPA1G160pp',
#  'PTRCabcpp',
#  'RFAMPtpp',
#  'PLIPA1G161pp',
#  'PUNP4',
#  'PLIPA1G180pp',
#  'PUNP6',
#  'PYAM5PO',
#  'PYDAMK',
#  'PYDXK',
#  'PYDXNK',
#  'PLIPA1G181pp',
#  'PYDXPP',
#  'PYROX',
#  'PLIPA2A120pp',
#  'SPMDt3pp',
#  'SPMS',
#  'PLIPA2A140pp',
#  'PLIPA2A141pp',
#  'SADH',
#  'PLIPA2A160pp',
#  'SUCCt2_3pp',
#  'SUCCt3pp',
#  'PLIPA2A161pp',
#  'SDPTA',
#  'PLIPA2A180pp',
#  'PLIPA2A181pp',
#  'SERASr',
#  'T2DECAI',
#  'PLIPA2E120pp',
#  'SGDS',
#  'PLIPA2E140pp',
#  'SGSAD',
#  'PLIPA2E141pp',
#  'TDP',
#  'THIORDXi',
#  'PLIPA2E160pp',
#  'SOTA',
#  'THRA2',
#  'PLIPA2E161pp',
#  'TYRTA',
#  'PLIPA2E180pp',
#  'THRabcpp',
#  'THRt2pp',
#  'PLIPA2E181pp',
#  'THYMt3pp',
#  'PLIPA2G120pp',
#  'TMDPP',
#  'PLIPA2G140pp',
#  'UDPG4E',
#  'TRDR',
#  'TRE6PP',
#  'TRE6PS',
#  'PLIPA2G141pp',
#  'TREH',
#  'TRPAS2',
#  'PLIPA2G160pp',
#  'PLIPA2G161pp',
#  'UM4PCP',
#  'PLIPA2G180pp',
#  'TTRCYCtex',
#  'TTRCYCtpp',
#  'UM4PL',
#  'UPPRT',
#  'URACPAH',
#  'PLIPA2G181pp',
#  'URDGLYCD',
#  'URIC',
#  'URIH',
#  'XAND',
#  'XANt2pp',
#  'VALabcpp',
#  'MDRPD',
#  'XYLabcpp',
#  'MME',
#  'MTRI',
#  'MTRK',
#  'ZN2abcpp',
#  'POAACR',
#  'UNK3',
#  'POX',
#  'PPA2',
#  'PPGPPDP',
#  'PPK',
#  'PPM',
#  'PPM2',
#  'DARBabcpp',
#  'DKMPPD',
#  'FLDR']

# %%
mon_incr
# Out:
# ['EX_cpgn_e',
#  'EX_isetac_e',
#  'EX_arbtn_fe3_e',
#  'EX_mso3_e',
#  'EX_no_e',
#  'EX_no2_e',
#  'EX_dmso_e',
#  'EX_no3_e',
#  'EX_orot_e',
#  '12PPDRtex',
#  '12PPDRtpp',
#  '12PPDStex',
#  '12PPDStpp',
#  'EX_skm_e',
#  'EX_sulfac_e',
#  'EX_taur_e',
#  'EX_tmao_e',
#  'EX_fe3dhbzs_e',
#  '2DGULRGx',
#  'EX_fe3hox_e',
#  'EX_fecrm_e',
#  'EX_feenter_e',
#  'EX_feoxam_e',
#  '3HPPtex',
#  'ABUTtex',
#  'ACACCT',
#  'ACALDtex',
#  'ACALDtpp',
#  'ACGAptspp',
#  'ACHBS',
#  '5DGLCNR',
#  '5DGLCNt2rpp',
#  'ACMANAptspp',
#  '5DGLCNtex',
#  'AKGt2rpp',
#  'AKGtex',
#  'ACSERtex',
#  'ALAALAtex',
#  'ACtex',
#  'ADEt2rpp',
#  'ADEtex',
#  'ADK4',
#  'ALAtex',
#  'ALCD19',
#  'ALCD2x',
#  'ALDD3y',
#  'ADNt2pp',
#  'ALLTNt2rpp',
#  'ALLTNtex',
#  'ALPATE160pp',
#  'ALPATG160pp',
#  'ANS',
#  'AGMtex',
#  'ANPRT',
#  'ASPtex',
#  'ATHRDHr',
#  'ATPPRT',
#  'BALAt2pp',
#  'CGLYtex',
#  'CHLt2pp',
#  'BETALDHy',
#  'BSORx',
#  'CHORM',
#  'CHORS',
#  'BUTCT',
#  'CITtex',
#  'CPPPGO',
#  'CRNDt2rpp',
#  'DADNt2pp',
#  'CSNt2pp',
#  'DALAtex',
#  'DAPDC',
#  'DAPE',
#  'DAPabcpp',
#  'CTBTt2rpp',
#  'DAPtex',
#  'CUt3',
#  'DCYTt2pp',
#  'DDGLK',
#  'DDPA',
#  'CYStex',
#  'DGSNt2pp',
#  'DHAD2',
#  'CYTDt2pp',
#  'DHAtex',
#  'DHAtpp',
#  'D_LACt2pp',
#  'DHDPRy',
#  'D_LACtex',
#  'DHQTi',
#  'DHDPS',
#  'DINSt2pp',
#  'DMSOR1',
#  'DMSOR1pp',
#  'DMSOR2',
#  'DMSOR2pp',
#  'DOGULNR',
#  'DHQS',
#  'DSBAO2',
#  'DSERDHr',
#  'DSERt2pp',
#  'ECOAH3',
#  'ECOAH4',
#  'ECOAH5',
#  'ECOAH6',
#  'ECOAH7',
#  'ECOAH8',
#  'DURIt2pp',
#  'ETHAtex',
#  'ETOHtex',
#  'ETOHtrpp',
#  'ARGtex',
#  'F6Pt6_2pp',
#  'FACOAL80t2pp',
#  'FESD2s',
#  'FORtex',
#  'ASNt2rpp',
#  'FRUpts2pp',
#  'ASNtex',
#  'FUMt2_2pp',
#  'G1PPpp',
#  'G2PPpp',
#  'G3PEtex',
#  'G3PGtex',
#  'G6Pt6_2pp',
#  'GLCNtex',
#  'GAL1PPpp',
#  'ASPO6',
#  'GLCptspp',
#  'GALKr',
#  'GALM2pp',
#  'GLNabcpp',
#  'GALt2pp',
#  'GALtex',
#  'GAM6Pt6_2pp',
#  'GLYCAtex',
#  'GAMptspp',
#  'GLUNpp',
#  'GLUtex',
#  'GLYALDtex',
#  'GLYALDtpp',
#  'GLYBt2pp',
#  'GUAtex',
#  'GUAtpp',
#  'GLYC3Ptex',
#  'GLYCAt2rpp',
#  'H2Stex',
#  'HXAtex',
#  'HYD2pp',
#  'HYD3pp',
#  'GLYCLTtex',
#  'HYXNtex',
#  'HYXNtpp',
#  'IDONt2rpp',
#  'IDONtex',
#  'IG3PS',
#  'IGPDH',
#  'IGPS',
#  'HEXt2rpp',
#  'HG2t3pp',
#  'ILEt2rpp',
#  'ILEtex',
#  'HISTD',
#  'HISTP',
#  'GLYCtex',
#  'HISt2rpp',
#  'HIStex',
#  'INDOLEtex',
#  'INSt2pp',
#  'HOMtex',
#  'IPMD',
#  'IPPS',
#  'HSTPT',
#  'KARA2',
#  'L_LACt2rpp',
#  'LACZ',
#  'LPLIPAL2ATE120',
#  'LALADGLUtpp',
#  'LPLIPAL2ATE140',
#  'GLYtex',
#  'LPLIPAL2ATE141',
#  'LPLIPAL2ATE160',
#  'LPLIPAL2ATE161',
#  'LALALGLUtpp',
#  'LPLIPAL2ATE180',
#  'LPLIPAL2ATE181',
#  'LPLIPAL2ATG120',
#  'LPLIPAL2ATG140',
#  'LPLIPAL2ATG141',
#  'LPLIPAL2ATG160',
#  'LPLIPAL2ATG161',
#  'LPLIPAL2ATG180',
#  'LPLIPAL2ATG181',
#  'LEUTAi',
#  'LEUt2rpp',
#  'LEUtex',
#  'LIPOCT',
#  'LYStex',
#  'MANptspp',
#  'MALtex',
#  'MAN6Pt6_2pp',
#  'METAT',
#  'GPDDA3pp',
#  'METSOX1abcpp',
#  'METSOX2abcpp',
#  'MLTP1',
#  'MLTP2',
#  'MLTP3',
#  'METabcpp',
#  'MG2t3_2pp',
#  'MNLptspp',
#  'NACtpp',
#  'GSNt2pp',
#  'NODOx',
#  'NMNPtpp',
#  'NO3R1pp',
#  'OMCDC',
#  'OMMBLHX',
#  'OMPHHX',
#  'OPHHX',
#  'ORNtex',
#  'OROTt2_2pp',
#  'PAPA120',
#  'PAPA140',
#  'PAPA141',
#  'PAPA160',
#  'PAPA161',
#  'PAPA180',
#  'PAPA181',
#  'PGMT',
#  'PRAIi',
#  'PRAMPC',
#  'PRATPP',
#  'PRMICI',
#  'PHEt2rpp',
#  'PHEtex',
#  'PROtex',
#  'PSCVT',
#  'PYRt2rpp',
#  'PYRtex',
#  'QMO2',
#  'PSP_Lpp',
#  'QUIN2tex',
#  'QUIN2tpp',
#  'QUINDH',
#  'RBK_L1',
#  'PTHRpp',
#  'PTRCORNt7pp',
#  'PTRCtex',
#  'RIBabcpp',
#  'PYDAMtpp',
#  'PYDXNtpp',
#  'PYDXtpp',
#  'SPMDtex',
#  'SPODM',
#  'SBTptspp',
#  'SDPDS',
#  'SUCCtex',
#  'SUCFUMtpp',
#  'SUCTARTtpp',
#  'TARTD',
#  'SERtex',
#  'SFGTHi',
#  'SHK3Dr',
#  'SHKK',
#  'SKMt2pp',
#  'SLNTtpp',
#  'THDPS',
#  'THMDt2pp',
#  'TYRt2rpp',
#  'TYRtex',
#  'THRtex',
#  'THYMtex',
#  'TMAOR1',
#  'TMAOR1pp',
#  'TMAOR2',
#  'TMAOR2pp',
#  'TREptspp',
#  'UGLT',
#  'TYRPpp',
#  'URAtex',
#  'UREAtex',
#  'PMANM',
#  'VALtex',
#  'UREAtpp',
#  'XANtex',
#  'URIt2pp',
#  'XANtpp',
#  'VALt2rpp',
#  'MECDPDH2',
#  'PNTOt4pp',
#  'XYLt2pp',
#  'PPAt4pp',
#  'PPBNGS',
#  'PPND',
#  'PPNDH',
#  'PPPGO3',
#  '2DGLCNRx',
#  'DURAD',
#  'TARTDC']

# %%
i2=0
mon_decr_and_stable= list()
mon_decr_only= list()

while i2< len(mon_decr):  #this code separates reactions that may have flat points from reactions that always decrease
    
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_lactose.csv'.format(mon_decr[i2]))
    i=0
    l= list()
    
    while i < 201:
        inf= csvFile.iloc[i,  2]
        flt= float(csvFile.iloc[i,  2])
    
        if csvFile.iloc[i,  2] == flt:
            l.append(csvFile.iloc[i,  2])
        i= i+1

    csvFile2= pd.DataFrame (l, columns = ['Biomass'])
    csvFile2.Biomass = csvFile2.Biomass.round(2)

    boolean = csvFile2["Biomass"].duplicated().any()
    
    if boolean == True:
        mon_decr_and_stable.append(mon_decr[i2])
    
    if boolean == False:
        mon_decr_only.append(mon_decr[i2])
    
    i2= i2+1

mon_decr_and_stable
# Out:
# ['EX_csn_e',
#  'EX_glcn_e',
#  'EX_glcur_e',
#  'EX_gln__L_e',
#  'EX_glyc2p_e',
#  'EX_glyclt_e',
#  'EX_hxan_e',
#  'EX_cys__L_e',
#  'EX_acgam1p_e',
#  'EX_alaala_e',
#  'EX_arg__L_e',
#  'EX_orn_e',
#  'EX_psclys_e',
#  'EX_r5p_e',
#  'EX_fald_e',
#  'EX_frulys_e',
#  'EX_fruur_e',
#  'EX_gal_bD_e',
#  'EX_gal1p_e',
#  'ACOLIPAabctex',
#  'ALAALAD',
#  'ALATA_D2',
#  'ALAabcpp',
#  'ALDD2x',
#  'EX_gam6p_e',
#  'ADNUC',
#  'ALDD2y',
#  'ADPT',
#  'AMPN',
#  'ASPabcpp',
#  'ASPt2_2pp',
#  'ASPt2_3pp',
#  'ASPt2pp_copy2',
#  'ATPM',
#  'CHLabcpp',
#  'CLIPAabctex',
#  'CD2abcpp',
#  'CMtpp',
#  'COBALT2abcpp',
#  'COLIPAabctex',
#  'CRNDabcpp',
#  'CRNabcpp',
#  'CTBTabcpp',
#  'CU1abcpp',
#  'CYSabc2pp',
#  'CYTBD2pp',
#  'CYTBDpp',
#  'ARBabcpp',
#  'ARBt3ipp',
#  'DOXRBCNtpp',
#  'ECA4COLIPAabctex',
#  'ENLIPAabctex',
#  'ARGabcpp',
#  'F6PP',
#  'FA120ACPHi',
#  'FA140ACPHi',
#  'FA141ACPHi',
#  'FA160ACPHi',
#  'FA161ACPHi',
#  'FBA3',
#  'FACOAL60t2pp',
#  'ASNNpp',
#  'FE2abcpp',
#  'FE2t2pp',
#  'ASNabcpp',
#  'FRD3',
#  'FTHFLi',
#  'FUMt2_3pp',
#  'FUSAtpp',
#  'G3PD5',
#  'G3PD6',
#  'G3PD7',
#  'ASPO3',
#  'G6PP',
#  'ASPO4',
#  'ASPO5',
#  'GLCabcpp',
#  'ASPT',
#  'GALabcpp',
#  'GLUN',
#  'GDPMNP',
#  'GLUabcpp',
#  'GLYBabcpp',
#  'GUAt2pp',
#  'GLYC3Pabcpp',
#  'HXPRT',
#  'IDOND2',
#  'HEX1',
#  'HG2abcpp',
#  'ILEabcpp',
#  'HISabcpp',
#  'INSH',
#  'HPYRRy',
#  'LCTSt3ipp',
#  'LCTStpp',
#  'LDH_D2',
#  'LEUabcpp',
#  'LIPAabctex',
#  'LYSabcpp',
#  'MALt2_3pp',
#  'MINCYCtpp',
#  'MDH2',
#  'MDH3',
#  'ME1',
#  'MLTG3',
#  'MLTG4',
#  'MLTG5',
#  'MN6PP',
#  'MG2tpp',
#  'MG2uabcpp',
#  'NADH10',
#  'NADH5',
#  'NADH9',
#  'NADPHQR2',
#  'NADPHQR3',
#  'NADPHQR4',
#  'NADTRHD',
#  'NAt3_1p5pp',
#  'NAt3_2pp',
#  'NOVBCNtpp',
#  'NI2abcpp',
#  'GTHPi',
#  'NTD7',
#  'NO3R2bpp',
#  'NTP1',
#  'NTP10',
#  'NTP3',
#  'NTP5',
#  'NTPP1',
#  'NTPP2',
#  'NTPP3',
#  'NTPP4',
#  'NTPP5',
#  'NTPP6',
#  'NTPP7',
#  'NTPP8',
#  'NTPTP2',
#  'ORNabcpp',
#  'OAADC',
#  'PFK',
#  'GUAPRT',
#  'PROabcpp',
#  'R5PP',
#  'PTRCabcpp',
#  'RFAMPtpp',
#  'SUCCt2_3pp',
#  'THIORDXi',
#  'THRA2',
#  'THRabcpp',
#  'TTRCYCtpp',
#  'UPPRT',
#  'URIH',
#  'XANt2pp',
#  'VALabcpp',
#  'XYLabcpp',
#  'ZN2abcpp',
#  'POX',
#  'PPA2',
#  'PPK',
#  'PPM',
#  'DARBabcpp',
#  'DKMPPD']

# %%
i2=0
mon_incr_and_stable= list()
mon_incr_only= list()

while i2< len(mon_incr):  #this code separates reactions that may have flat points from reactions that always increase
    
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_lactose.csv'.format(mon_incr[i2]))
    i=0
    l= list()
    
    while i < 201:
        inf= csvFile.iloc[i,  2]
        flt= float(csvFile.iloc[i,  2])
    
        if csvFile.iloc[i,  2] == flt:
            l.append(csvFile.iloc[i,  2])
        i= i+1

    csvFile2= pd.DataFrame (l, columns = ['Biomass'])
    csvFile2.Biomass = csvFile2.Biomass.round(2)

    boolean = csvFile2["Biomass"].duplicated().any()
    
    if boolean == True:
        mon_incr_and_stable.append(mon_incr[i2])
    
    if boolean == False:
        mon_incr_only.append(mon_incr[i2])
    
    i2= i2+1

mon_incr_and_stable
# Out:
# ['CRNDt2rpp',
#  'DMSOR1',
#  'DMSOR1pp',
#  'DMSOR2',
#  'DMSOR2pp',
#  'DSBAO2',
#  'FRUpts2pp',
#  'GLCptspp',
#  'GALt2pp',
#  'HYD2pp',
#  'HYD3pp',
#  'LACZ',
#  'NO3R1pp',
#  'QMO2',
#  'SPODM',
#  'TMAOR1',
#  'TMAOR1pp',
#  'TMAOR2',
#  'TMAOR2pp',
#  'MECDPDH2',
#  'DURAD']

# %%
d.iloc[len(d)-1,0]
# Out:
# 0.0185680575863063

# %%
set1= set(diff_indecr)
set2= set(mon_decr)
set3= set(mon_incr)
inANDdecr= list(set1-set2-set3)
inANDdecr
# Out:
# ['OCBT',
#  'GLCt2pp',
#  'DKMPPD3',
#  'CLPNH160pp',
#  'TRE6PH',
#  'LPLIPAL2E141',
#  'ARBTNR1',
#  'NH4tpp',
#  'DASYN160',
#  'GF6PTA',
#  'TKT2',
#  'PRFGS',
#  'FLDR2',
#  'TMDS',
#  'GLUPRT',
#  'FA80ACPHi',
#  'G3PEabcpp',
#  'CMPN',
#  'EX_LalaLglu_e',
#  'NI2t3pp',
#  'NI2uabcpp',
#  'ARGSL',
#  'AIRC3',
#  'G1PACT',
#  'EX_but_e',
#  'FECRMR3',
#  'EX_tartr__D_e',
#  'HSK',
#  '2AGPEAT161',
#  'EX_octa_e',
#  'FACOAE120',
#  '2AGPEAT140',
#  'MOX',
#  'RPI',
#  'AIRC2',
#  'EX_hdcea_e',
#  'EX_udpglcur_e',
#  'TRPS3',
#  'CYTK1',
#  'THRS',
#  'FEENTERR2',
#  'EX_udpgal_e',
#  'NDPK4',
#  'PSSA161',
#  'NH4tex',
#  'NADH17pp',
#  'GMPS2',
#  'ACODA',
#  'MLTGY1pp',
#  'EX_gal_e',
#  'P5CR',
#  'IMPC',
#  'RNTR1c2',
#  'NDPK2',
#  'GDPTPDP',
#  'PA180abcpp',
#  '2AGPEAT141',
#  'EX_galct__D_e',
#  'DHAD1',
#  'COBALT2t3pp',
#  'LYSt2pp',
#  'MACPD',
#  'MNt2pp',
#  'NMNN',
#  'ECOAH1',
#  'EX_fru_e',
#  'CAT',
#  'EX_uacgam_e',
#  '2AGPGAT181',
#  'CO2tpp',
#  'FORt2pp',
#  'PGI',
#  'EX_manglyc_e',
#  'CLPNH140pp',
#  'CDAPPA141',
#  'GLUSy',
#  'GLUR',
#  'FACOAE161',
#  'PGK',
#  'EAR120x',
#  'PPCK',
#  'CYTK2',
#  'RPE',
#  'UAPGR',
#  'EX_acnam_e',
#  '4PCP',
#  'PA140abcpp',
#  'PSD161',
#  'FE3HOXR1',
#  'CLPNH161pp',
#  'EX_agm_e',
#  'XYLI2',
#  'EX_LalaDgluMdap_e',
#  'APH141',
#  'ADSK',
#  'AGPR',
#  'COBALT2tpp',
#  '2AGPGAT180',
#  'DCTPD',
#  'PGL',
#  'DGK1',
#  'THRt4pp',
#  'EX_gam_e',
#  'NTD1',
#  'XPPT',
#  'AACPS4',
#  'AGM3PApp',
#  '2AGPEAT120',
#  'GHMT2r',
#  'EX_anhgm_e',
#  'GLUTRS',
#  'MCOATA',
#  'EX_fum_e',
#  'PGAMT',
#  'EX_sucr_e',
#  'PGM',
#  '3OAS140',
#  'CS',
#  'PA120abcpp',
#  'EAR180x',
#  'EX_3hcinnm_e',
#  'IDOND',
#  'ENTERES',
#  'ACOTA',
#  'DHFR',
#  'GAPD',
#  '2AGPEAT181',
#  'EX_h2_e',
#  'PRPPS',
#  'RNDR4',
#  'EX_idon__L_e',
#  'AICART',
#  'CLPNH180pp',
#  'PTAr',
#  'CLPNH141pp',
#  'CYTBO3_4pp',
#  'EX_sbt__D_e',
#  'SO4tex',
#  'NACODA',
#  'CPGNR2',
#  'EX_butso3_e',
#  'FE3HOXR2',
#  'MLDCP2Bpp',
#  'APH120',
#  'PA181abcpp',
#  'GSNK',
#  'NADK',
#  'EX_glyc__R_e',
#  'GK1',
#  'ADNK1',
#  'FACOAE140',
#  'NADH18pp',
#  'LPLIPAL2E161',
#  'GLNS',
#  'CDAPPA120',
#  'FACOAE80',
#  'ASPTA',
#  'AGM4PA',
#  'G1SAT',
#  'NTRIR3pp',
#  'CLPNH120pp',
#  'ACGS',
#  'EX_hdca_e',
#  'ENO',
#  'MPTG',
#  'PYK',
#  'NDPK3',
#  'GLYCTO3',
#  'GLYCDx',
#  'EX_ttdca_e',
#  'EX_o2_e',
#  'PSSA160',
#  'EX_galt_e',
#  'GLYCL',
#  'PGCD',
#  'EX_ac_e',
#  'PAPPT3',
#  'RNDR4b',
#  'APH180',
#  'LDH_D',
#  'PAPSR2',
#  'MTHFC',
#  'FUM',
#  'EX_cynt_e',
#  'MALt2_2pp',
#  'UAGDP',
#  'GLUDC',
#  'EX_fe3dcit_e',
#  'GART',
#  'F6PA',
#  'EAR140x',
#  'GLUTRR',
#  'GARFT',
#  'EX_LalaDgluMdapDala_e',
#  'SSALy',
#  'DASYN161',
#  'PGPP161',
#  'EX_12ppd__S_e',
#  'EX_acmum_e',
#  'ASAD',
#  'EX_rib__D_e',
#  'GTHRDabcpp',
#  'CU2tpp',
#  'EX_ptrc_e',
#  'GLUDy',
#  'PGPP160',
#  'RNDR1b',
#  'G3PGabcpp',
#  'APH140',
#  'GLYC3Pt6pp',
#  'EX_lcts_e',
#  'EX_pppn_e',
#  'EX_ocdcea_e',
#  'OPHHX3',
#  'ICDHyr',
#  'PUNP2',
#  'EX_val__L_e',
#  'SUCMALtpp',
#  'EX_acmana_e',
#  'RNDR3',
#  'CDAPPA140',
#  'O2tex',
#  'PROD2',
#  'LPLIPAL2G181',
#  'ICL',
#  'EX_xan_e',
#  'EAR160x',
#  'EX_26dap__M_e',
#  'EX_3hpppn_e',
#  'CD2t3pp',
#  'ALAALAabcpp',
#  '2AGPGAT161',
#  'DURIK1',
#  'UAGPT3',
#  'CYSS',
#  '2AGPEAT160',
#  'EX_ocdca_e',
#  'UGMDDS',
#  'PPA',
#  'GLYCtpp',
#  'DTMPK',
#  'KARA1',
#  'NDPK5',
#  'AGM4PCPpp',
#  'PIt2rpp',
#  'NTD11',
#  'CYTDK2',
#  'SULR',
#  'CDAPPA180',
#  'EX_gthrd_e',
#  'EX_pi_e',
#  'PPS',
#  'RNDR2b',
#  'LPLIPAL2G140',
#  'ALAALAr',
#  'INSK',
#  'PSP_L',
#  'FE2tpp',
#  'FEOXAMR2',
#  'CYSabcpp',
#  'EX_pro__L_e',
#  'GDPMNH',
#  'EX_glcr_e',
#  'FE3HOXR3',
#  'AGPAT161',
#  'FBA',
#  'EX_ttdcea_e',
#  'ARBTNR2',
#  'PGPP181',
#  'PGPP180',
#  'EX_nh4_e',
#  'GLYCLTDx',
#  'AACPS6',
#  'EX_galctn__D_e',
#  'NDPK8',
#  'ASNN',
#  'EX_23dappa_e',
#  'FACOAE160',
#  'BPNT',
#  'CDAPPA181',
#  'LPLIPAL2E181',
#  'TPI',
#  'DHORD5',
#  'O2tpp',
#  'AACPS5',
#  'EAR141x',
#  'ZNabcpp',
#  'CLPNH181pp',
#  'APG3PAT161',
#  'THD2pp',
#  'PUNP1',
#  'EX_23ccmp_e',
#  'GLYCTO4',
#  'EX_indole_e',
#  'ACONTa',
#  'H2Otex',
#  'LPLIPAL2G160',
#  'ARBTNR3',
#  'PE160abcpp',
#  'EX_ala__D_e',
#  'GUAD',
#  'LPLIPAL2G141',
#  'FECRMR2',
#  'SUCDi',
#  '2AGPGAT160',
#  'FEENTERR3',
#  'EX_dca_e',
#  'RNDR2',
#  'EX_etoh_e',
#  'GNK',
#  'OMPDC',
#  'PA161abcpp',
#  'PYRDC',
#  'Kt2pp',
#  'H2SO',
#  'EX_ascb__L_e',
#  'RNTR4c',
#  '2AGPGAT141',
#  'ECOAH2',
#  '4PEPTabcpp',
#  'EX_malt_e',
#  'EX_acgam_e',
#  'EAR161x',
#  'ZN2tpp',
#  'TMPK',
#  'EX_gua_e',
#  'POR5',
#  'EX_man_e',
#  'NMNDA',
#  'FACOAE180',
#  'GND',
#  '2AGPGAT120',
#  'PGPP140',
#  'G3PD2',
#  'ALATA_L2',
#  'ETHAt2pp',
#  'PMPK',
#  'ACGK',
#  'UMPK',
#  'UAMAS',
#  'FRD2',
#  'SPMDabcpp',
#  'EX_galur_e',
#  'RNTR1c',
#  'UAAGDS',
#  'NMNAT',
#  'UM3PL',
#  'EX_LalaDglu_e',
#  'OBTFL',
#  'HEX7',
#  'FACOAE181',
#  'CYTD',
#  'OMMBLHX3',
#  'MLDEP2pp',
#  'PGPP120',
#  'AM4PA',
#  'EX_quin_e',
#  'ACKr',
#  'RNTR2c2',
#  'NTD2',
#  'EX_succ_e',
#  'EX_lyx__L_e',
#  'SULabcpp',
#  'NTD6',
#  'AM4PCP',
#  'PSD160',
#  'ACOAD1f',
#  'EX_melib_e',
#  'CYSDS',
#  'EX_chtbs_e',
#  'LPLIPAL2E120',
#  'ACOAD2f',
#  'MTHFD',
#  'FACOAE141',
#  'ORNDC',
#  'AGM3Pt2pp',
#  'EX_hxa_e',
#  'EX_xylu__L_e',
#  'ACPPAT160',
#  'HCO3E',
#  'AGM3PH',
#  'FEOXAMR1',
#  'HXCT',
#  'PAPSR',
#  'EX_ura_e',
#  'EX_udpacgal_e',
#  'AGM4PCP',
#  'EAR60x',
#  'Kabcpp',
#  'PIuabcpp',
#  'MLTGY2pp',
#  'PRAGSr',
#  'SADT2',
#  'TMDK1',
#  'ADSL1r',
#  'EAR100x',
#  'MN2tpp',
#  'NDPK7',
#  'CO2tex',
#  'RNTR3c2',
#  'ARGAGMt7pp',
#  'EX_ethso3_e',
#  'EX_glc__D_e',
#  'RNTR2c',
#  'AACPS1',
#  'EX_tartr__L_e',
#  'ATPS4rpp',
#  'PFL',
#  'IMPD',
#  'EX_progly_e',
#  'PGPP141',
#  'FA100ACPHi',
#  'UGLYCH',
#  'PFK_3',
#  '2AGPEAT180',
#  'EX_asn__L_e',
#  'UAMAGS',
#  'CBPS',
#  'FLVRx',
#  'EX_udpg_e',
#  'EX_h2o_e',
#  'AACPS2',
#  'EX_cgly_e',
#  'G6PDA',
#  'NADH16pp',
#  'FADRx',
#  'APH161',
#  'EX_ddca_e',
#  'DALAt2pp',
#  'AGPAT160',
#  '2AGPGAT140',
#  'EX_for_e',
#  'OMPHHX3',
#  'SERAT',
#  'LALDO2x',
#  'SO4t2pp',
#  'CITL',
#  'ARGSS',
#  'GPDDA4pp',
#  'PUNP3',
#  'RNDR1',
#  'GLYAT',
#  'ARBt2rpp',
#  'EX_co2_e',
#  'P5CD',
#  'GLYK',
#  'LPLIPAL2E140',
#  'FBP',
#  'PItex',
#  'FE3abcpp',
#  'FACOAE100',
#  'EX_ade_e',
#  'HSDy',
#  'HXAND',
#  'ACALD',
#  'AACPS3',
#  'FMNRx',
#  'EX_xyl__D_e',
#  'ACCOAC',
#  'NNATr',
#  '4PCPpp',
#  'ME2',
#  'EX_ppa_e',
#  'APH181',
#  'SUCASPtpp',
#  'NTRIR2x',
#  'PA141abcpp',
#  'THRD_L',
#  'FECRMR1',
#  'GMPR',
#  'PTRCt2pp',
#  'CDAPPA160',
#  'EX_glyc_e',
#  'EX_ppal_e',
#  'CDAPPA161',
#  'PA160abcpp',
#  'LPLIPAL2G120',
#  'LPLIPAL2E180',
#  'PPPGO',
#  'H2Otpp',
#  'EX_g1p_e',
#  'PPC',
#  'EAR181x',
#  'NADS1',
#  'ZN2t3pp',
#  'NTD9',
#  'GDPDPK',
#  'UDCPDP',
#  'G6PDH2r',
#  'RNTR4c2',
#  'EX_tre_e',
#  'EX_arab__L_e',
#  'EAR40x',
#  'CYStpp',
#  'PSERT',
#  'LPLIPAL2G180',
#  'EX_so4_e',
#  'MCTP1App',
#  'APG3PAT160',
#  'MALS',
#  'TKT1',
#  'FEENTERR1',
#  'PE161abcpp',
#  'PYNP2r',
#  'PUNP5',
#  'LPLIPAL2E160',
#  'PRAIS',
#  'PRASCSi',
#  'ACONTb',
#  'TALA',
#  'DADK',
#  'LPLIPAL2G161',
#  'EX_mnl_e',
#  'ALAR',
#  'EX_alltn_e',
#  'PDH',
#  'ORPT',
#  'EX_galctn__L_e',
#  'CYTDH',
#  'URIK2',
#  'ACPPAT161',
#  'AGM3PA',
#  'ACLS',
#  'UAGCVT',
#  'ADSS',
#  'EX_4abut_e',
#  'FTHFD',
#  'MGSA',
#  'CTPS2',
#  'DURIPP',
#  'RNDR3b',
#  '3OAR140',
#  'G5SADs',
#  'ARGDC',
#  'FDH5pp',
#  'ASPK',
#  'MLDCP1Bpp',
#  'AACPS7',
#  'EAR121x',
#  'APH160',
#  'MDH',
#  'DHORTS',
#  'SUCCt2_2pp',
#  'MDDEP3pp',
#  'NO3R1bpp',
#  'RNTR3c',
#  'AKGDH',
#  'G3PT',
#  'CPGNR1',
#  'ENTERES2',
#  'ASPCT',
#  'CBMKr',
#  'CPGNR3',
#  'ASNS2',
#  'NI2tpp',
#  'MDDCP1pp',
#  'ARGDCpp',
#  'FEOXAMR3',
#  'PPK2',
#  'EX_all__D_e',
#  'EAR80x',
#  'ADSL2r',
#  'ACOATA']

# %%
i2=0
inANDdecr_and_stable= list()

while i2< len(inANDdecr):  #this code separates reactions that may have flat points from reactions that always increase and decrease
    
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_lactose.csv'.format(inANDdecr[i2]))
    i=0
    l= list()
    
    while i < 201:
        inf= csvFile.iloc[i,  2]
        flt= float(csvFile.iloc[i,  2])
    
        if csvFile.iloc[i,  2] == flt:
            l.append(csvFile.iloc[i,  2])
        
        i= i+1

    csvFile2= pd.DataFrame (l, columns = ['Biomass'])
    csvFile2.Biomass = csvFile2.Biomass.round(2)
    
    i=0
    
    while i < len(csvFile2)-1:
        if csvFile2.iloc[i,  0] == csvFile2.iloc[i+1,  0] and inANDdecr[i2] not in inANDdecr_and_stable:
            inANDdecr_and_stable.append(inANDdecr[i2])
            
        i=i+1
        
    i2= i2+1

inANDdecr_and_stable
# Out:
# ['FLDR2',
#  'NI2uabcpp',
#  'EX_udpgal_e',
#  'NH4tex',
#  'NADH17pp',
#  'EX_gal_e',
#  'MNt2pp',
#  'EX_fru_e',
#  'EX_uacgam_e',
#  'CO2tpp',
#  'EX_manglyc_e',
#  'GLUSy',
#  'PPCK',
#  'EX_agm_e',
#  'XYLI2',
#  'EX_gam_e',
#  'EX_h2_e',
#  'PRPPS',
#  'PTAr',
#  'EX_sbt__D_e',
#  'GSNK',
#  'EX_glyc__R_e',
#  'ADNK1',
#  'NADH18pp',
#  'NTRIR3pp',
#  'PYK',
#  'GLYCTO3',
#  'EX_o2_e',
#  'EX_ac_e',
#  'EX_cynt_e',
#  'GART',
#  'F6PA',
#  'EX_rib__D_e',
#  'EX_ptrc_e',
#  'OPHHX3',
#  'O2tex',
#  'PPA',
#  'INSK',
#  'EX_pro__L_e',
#  'FBA',
#  'EX_nh4_e',
#  'EX_galctn__D_e',
#  'ASNN',
#  'DHORD5',
#  'ZNabcpp',
#  'GLYCTO4',
#  'H2Otex',
#  'SUCDi',
#  'PYRDC',
#  'H2SO',
#  'EX_gua_e',
#  'EX_man_e',
#  'ALATA_L2',
#  'FRD2',
#  'HEX7',
#  'OMMBLHX3',
#  'ACKr',
#  'EX_lyx__L_e',
#  'SULabcpp',
#  'EX_xylu__L_e',
#  'HXCT',
#  'Kabcpp',
#  'PIuabcpp',
#  'EX_glc__D_e',
#  'PFK_3',
#  'CBPS',
#  'EX_udpg_e',
#  'EX_h2o_e',
#  'NADH16pp',
#  'EX_for_e',
#  'OMPHHX3',
#  'FE3abcpp',
#  'ACALD',
#  'EX_xyl__D_e',
#  'EX_ppa_e',
#  'NTRIR2x',
#  'EX_glyc_e',
#  'EX_ppal_e',
#  'PPPGO',
#  'EX_g1p_e',
#  'NTD9',
#  'EX_arab__L_e',
#  'TALA',
#  'EX_mnl_e',
#  'PDH',
#  'EX_galctn__L_e',
#  'URIK2',
#  'FDH5pp',
#  'NO3R1bpp',
#  'AKGDH',
#  'ARGDCpp']

# %%
set1= set(inANDdecr)
set2= set(inANDdecr_and_stable)
l_left= list(set1-set2)
l_left

i2=0
inANDdecr_only= list()

while i2< len(l_left):  #this code separates reactions that may have flat points from reactions that always increase and decrease
    
    csvFile = pd.read_csv('biomass_per_flux_for_reaction_{}_lactose.csv'.format(l_left[i2]))
    i=0
    l= list()
    
    while i < 201:
        inf= csvFile.iloc[i,  2]
        flt= float(csvFile.iloc[i,  2])
    
        if csvFile.iloc[i,  2] == flt:
            l.append(csvFile.iloc[i,  2])
        
        i= i+1

    csvFile2= pd.DataFrame (l, columns = ['Biomass'])
    csvFile2.Biomass = csvFile2.Biomass.round(2)
    
    i=0
        
    while i < len(csvFile2)-1:
        
        if csvFile2.iloc[i,  0] != csvFile2.iloc[i+1,  0] and l_left[i2] not in inANDdecr_only:
            inANDdecr_only.append(l_left[i2])
        
        i=i+1
        
    i2= i2+1

inANDdecr_only
# Out:
# ['OCBT',
#  'GLCt2pp',
#  'DKMPPD3',
#  'CLPNH160pp',
#  'TRE6PH',
#  'LPLIPAL2E141',
#  'ARBTNR1',
#  'NH4tpp',
#  'DASYN160',
#  'GF6PTA',
#  'TKT2',
#  'PRFGS',
#  'TMDS',
#  'GLUPRT',
#  'FA80ACPHi',
#  'G3PEabcpp',
#  'CMPN',
#  'EX_LalaLglu_e',
#  'NI2t3pp',
#  'ARGSL',
#  'AIRC3',
#  'G1PACT',
#  'EX_but_e',
#  'FECRMR3',
#  'EX_tartr__D_e',
#  'HSK',
#  '2AGPEAT161',
#  'EX_octa_e',
#  'FACOAE120',
#  '2AGPEAT140',
#  'MOX',
#  'RPI',
#  'AIRC2',
#  'EX_hdcea_e',
#  'EX_udpglcur_e',
#  'TRPS3',
#  'CYTK1',
#  'THRS',
#  'FEENTERR2',
#  'NDPK4',
#  'PSSA161',
#  'GMPS2',
#  'ACODA',
#  'MLTGY1pp',
#  'P5CR',
#  'IMPC',
#  'RNTR1c2',
#  'NDPK2',
#  'GDPTPDP',
#  'PA180abcpp',
#  '2AGPEAT141',
#  'EX_galct__D_e',
#  'DHAD1',
#  'COBALT2t3pp',
#  'LYSt2pp',
#  'MACPD',
#  'NMNN',
#  'ECOAH1',
#  'CAT',
#  '2AGPGAT181',
#  'FORt2pp',
#  'PGI',
#  'CLPNH140pp',
#  'CDAPPA141',
#  'GLUR',
#  'FACOAE161',
#  'PGK',
#  'EAR120x',
#  'CYTK2',
#  'RPE',
#  'UAPGR',
#  'EX_acnam_e',
#  '4PCP',
#  'PA140abcpp',
#  'PSD161',
#  'FE3HOXR1',
#  'CLPNH161pp',
#  'EX_LalaDgluMdap_e',
#  'APH141',
#  'ADSK',
#  'AGPR',
#  'COBALT2tpp',
#  '2AGPGAT180',
#  'DCTPD',
#  'PGL',
#  'DGK1',
#  'THRt4pp',
#  'NTD1',
#  'XPPT',
#  'AACPS4',
#  'AGM3PApp',
#  '2AGPEAT120',
#  'GHMT2r',
#  'EX_anhgm_e',
#  'GLUTRS',
#  'MCOATA',
#  'EX_fum_e',
#  'PGAMT',
#  'EX_sucr_e',
#  'PGM',
#  '3OAS140',
#  'CS',
#  'PA120abcpp',
#  'EAR180x',
#  'EX_3hcinnm_e',
#  'IDOND',
#  'ENTERES',
#  'ACOTA',
#  'DHFR',
#  'GAPD',
#  '2AGPEAT181',
#  'RNDR4',
#  'EX_idon__L_e',
#  'AICART',
#  'CLPNH180pp',
#  'CLPNH141pp',
#  'CYTBO3_4pp',
#  'SO4tex',
#  'NACODA',
#  'CPGNR2',
#  'EX_butso3_e',
#  'FE3HOXR2',
#  'MLDCP2Bpp',
#  'APH120',
#  'PA181abcpp',
#  'NADK',
#  'GK1',
#  'FACOAE140',
#  'LPLIPAL2E161',
#  'GLNS',
#  'CDAPPA120',
#  'FACOAE80',
#  'ASPTA',
#  'AGM4PA',
#  'G1SAT',
#  'CLPNH120pp',
#  'ACGS',
#  'EX_hdca_e',
#  'ENO',
#  'MPTG',
#  'NDPK3',
#  'GLYCDx',
#  'EX_ttdca_e',
#  'PSSA160',
#  'EX_galt_e',
#  'GLYCL',
#  'PGCD',
#  'PAPPT3',
#  'RNDR4b',
#  'APH180',
#  'LDH_D',
#  'PAPSR2',
#  'MTHFC',
#  'FUM',
#  'MALt2_2pp',
#  'UAGDP',
#  'GLUDC',
#  'EX_fe3dcit_e',
#  'EAR140x',
#  'GLUTRR',
#  'GARFT',
#  'EX_LalaDgluMdapDala_e',
#  'SSALy',
#  'DASYN161',
#  'PGPP161',
#  'EX_12ppd__S_e',
#  'EX_acmum_e',
#  'ASAD',
#  'GTHRDabcpp',
#  'CU2tpp',
#  'GLUDy',
#  'PGPP160',
#  'RNDR1b',
#  'G3PGabcpp',
#  'APH140',
#  'GLYC3Pt6pp',
#  'EX_lcts_e',
#  'EX_pppn_e',
#  'EX_ocdcea_e',
#  'ICDHyr',
#  'PUNP2',
#  'EX_val__L_e',
#  'SUCMALtpp',
#  'EX_acmana_e',
#  'RNDR3',
#  'CDAPPA140',
#  'PROD2',
#  'LPLIPAL2G181',
#  'ICL',
#  'EX_xan_e',
#  'EAR160x',
#  'EX_26dap__M_e',
#  'EX_3hpppn_e',
#  'CD2t3pp',
#  'ALAALAabcpp',
#  '2AGPGAT161',
#  'DURIK1',
#  'UAGPT3',
#  'CYSS',
#  '2AGPEAT160',
#  'EX_ocdca_e',
#  'UGMDDS',
#  'GLYCtpp',
#  'DTMPK',
#  'KARA1',
#  'NDPK5',
#  'AGM4PCPpp',
#  'PIt2rpp',
#  'NTD11',
#  'CYTDK2',
#  'SULR',
#  'CDAPPA180',
#  'EX_gthrd_e',
#  'EX_pi_e',
#  'PPS',
#  'RNDR2b',
#  'LPLIPAL2G140',
#  'ALAALAr',
#  'PSP_L',
#  'FE2tpp',
#  'FEOXAMR2',
#  'CYSabcpp',
#  'GDPMNH',
#  'EX_glcr_e',
#  'FE3HOXR3',
#  'AGPAT161',
#  'EX_ttdcea_e',
#  'ARBTNR2',
#  'PGPP181',
#  'PGPP180',
#  'GLYCLTDx',
#  'AACPS6',
#  'NDPK8',
#  'EX_23dappa_e',
#  'FACOAE160',
#  'BPNT',
#  'CDAPPA181',
#  'LPLIPAL2E181',
#  'TPI',
#  'O2tpp',
#  'AACPS5',
#  'EAR141x',
#  'CLPNH181pp',
#  'APG3PAT161',
#  'THD2pp',
#  'PUNP1',
#  'EX_23ccmp_e',
#  'EX_indole_e',
#  'ACONTa',
#  'LPLIPAL2G160',
#  'ARBTNR3',
#  'PE160abcpp',
#  'EX_ala__D_e',
#  'GUAD',
#  'LPLIPAL2G141',
#  'FECRMR2',
#  '2AGPGAT160',
#  'FEENTERR3',
#  'EX_dca_e',
#  'RNDR2',
#  'EX_etoh_e',
#  'GNK',
#  'OMPDC',
#  'PA161abcpp',
#  'Kt2pp',
#  'EX_ascb__L_e',
#  'RNTR4c',
#  '2AGPGAT141',
#  'ECOAH2',
#  '4PEPTabcpp',
#  'EX_malt_e',
#  'EX_acgam_e',
#  'EAR161x',
#  'ZN2tpp',
#  'TMPK',
#  'POR5',
#  'NMNDA',
#  'FACOAE180',
#  'GND',
#  '2AGPGAT120',
#  'PGPP140',
#  'G3PD2',
#  'ETHAt2pp',
#  'PMPK',
#  'ACGK',
#  'UMPK',
#  'UAMAS',
#  'SPMDabcpp',
#  'EX_galur_e',
#  'RNTR1c',
#  'UAAGDS',
#  'NMNAT',
#  'UM3PL',
#  'EX_LalaDglu_e',
#  'OBTFL',
#  'FACOAE181',
#  'CYTD',
#  'MLDEP2pp',
#  'PGPP120',
#  'AM4PA',
#  'EX_quin_e',
#  'RNTR2c2',
#  'NTD2',
#  'EX_succ_e',
#  'NTD6',
#  'AM4PCP',
#  'PSD160',
#  'ACOAD1f',
#  'EX_melib_e',
#  'CYSDS',
#  'EX_chtbs_e',
#  'LPLIPAL2E120',
#  'ACOAD2f',
#  'MTHFD',
#  'FACOAE141',
#  'ORNDC',
#  'AGM3Pt2pp',
#  'EX_hxa_e',
#  'ACPPAT160',
#  'HCO3E',
#  'AGM3PH',
#  'FEOXAMR1',
#  'PAPSR',
#  'EX_ura_e',
#  'EX_udpacgal_e',
#  'AGM4PCP',
#  'EAR60x',
#  'MLTGY2pp',
#  'PRAGSr',
#  'SADT2',
#  'TMDK1',
#  'ADSL1r',
#  'EAR100x',
#  'MN2tpp',
#  'NDPK7',
#  'CO2tex',
#  'RNTR3c2',
#  'ARGAGMt7pp',
#  'EX_ethso3_e',
#  'RNTR2c',
#  'AACPS1',
#  'EX_tartr__L_e',
#  'ATPS4rpp',
#  'PFL',
#  'IMPD',
#  'EX_progly_e',
#  'PGPP141',
#  'FA100ACPHi',
#  'UGLYCH',
#  '2AGPEAT180',
#  'EX_asn__L_e',
#  'UAMAGS',
#  'FLVRx',
#  'AACPS2',
#  'EX_cgly_e',
#  'G6PDA',
#  'FADRx',
#  'APH161',
#  'EX_ddca_e',
#  'DALAt2pp',
#  'AGPAT160',
#  '2AGPGAT140',
#  'SERAT',
#  'LALDO2x',
#  'SO4t2pp',
#  'CITL',
#  'ARGSS',
#  'GPDDA4pp',
#  'PUNP3',
#  'RNDR1',
#  'GLYAT',
#  'ARBt2rpp',
#  'EX_co2_e',
#  'P5CD',
#  'GLYK',
#  'LPLIPAL2E140',
#  'FBP',
#  'PItex',
#  'FACOAE100',
#  'EX_ade_e',
#  'HSDy',
#  'HXAND',
#  'AACPS3',
#  'FMNRx',
#  'ACCOAC',
#  'NNATr',
#  '4PCPpp',
#  'ME2',
#  'APH181',
#  'SUCASPtpp',
#  'PA141abcpp',
#  'THRD_L',
#  'FECRMR1',
#  'GMPR',
#  'PTRCt2pp',
#  'CDAPPA160',
#  'CDAPPA161',
#  'PA160abcpp',
#  'LPLIPAL2G120',
#  'LPLIPAL2E180',
#  'H2Otpp',
#  'PPC',
#  'EAR181x',
#  'NADS1',
#  'ZN2t3pp',
#  'GDPDPK',
#  'UDCPDP',
#  'G6PDH2r',
#  'RNTR4c2',
#  'EX_tre_e',
#  'EAR40x',
#  'CYStpp',
#  'PSERT',
#  'LPLIPAL2G180',
#  'EX_so4_e',
#  'MCTP1App',
#  'APG3PAT160',
#  'MALS',
#  'TKT1',
#  'FEENTERR1',
#  'PE161abcpp',
#  'PYNP2r',
#  'PUNP5',
#  'LPLIPAL2E160',
#  'PRAIS',
#  'PRASCSi',
#  'ACONTb',
#  'DADK',
#  'LPLIPAL2G161',
#  'ALAR',
#  'EX_alltn_e',
#  'ORPT',
#  'CYTDH',
#  'ACPPAT161',
#  'AGM3PA',
#  'ACLS',
#  'UAGCVT',
#  'ADSS',
#  'EX_4abut_e',
#  'FTHFD',
#  'MGSA',
#  'CTPS2',
#  'DURIPP',
#  'RNDR3b',
#  '3OAR140',
#  'G5SADs',
#  'ARGDC',
#  'ASPK',
#  'MLDCP1Bpp',
#  'AACPS7',
#  'EAR121x',
#  'APH160',
#  'MDH',
#  'DHORTS',
#  'SUCCt2_2pp',
#  'MDDEP3pp',
#  'RNTR3c',
#  'G3PT',
#  'CPGNR1',
#  'ENTERES2',
#  'ASPCT',
#  'CBMKr',
#  'CPGNR3',
#  'ASNS2',
#  'NI2tpp',
#  'MDDCP1pp',
#  'FEOXAMR3',
#  'PPK2',
#  'EX_all__D_e',
#  'EAR80x',
#  'ADSL2r',
#  'ACOATA']

# %%
len(one)
# Out:
# 967

# %%
d1= pd.DataFrame (mon_decr, columns = ['Reaction names'])
d2= pd.DataFrame (flat, columns = ['Reaction names'])
d3= pd.DataFrame (diff_saturatedFINAL, columns = ['Reaction names'])
d4= pd.DataFrame (Ushaped_reactions, columns = ['Reaction names'])
d5= pd.DataFrame (mon_decr_and_stable, columns = ['Reaction names'])
d6= pd.DataFrame (mon_decr_only, columns = ['Reaction names'])
d7= pd.DataFrame (mon_incr_and_stable, columns = ['Reaction names'])
d8= pd.DataFrame (mon_incr_only, columns = ['Reaction names'])
d9= pd.DataFrame (inANDdecr_and_stable, columns = ['Reaction names'])
d10= pd.DataFrame (inANDdecr_only, columns = ['Reaction names'])

D.to_csv("one feasible value reactions lactose.csv")
d1.to_csv("monotonically decreasing reactions lactose.csv")
d2.to_csv("flat lactose.csv")
d3.to_csv("diff_saturated lactose.csv")
d4.to_csv("Ushaped_reactions lactose.csv")
d5.to_csv("monotonically decreasing and stable reactions lactose.csv")
d6.to_csv("monotonically decreasing only reactions lactose.csv")
d7.to_csv("monotonically increasing and stable reactions lactose.csv")
d8.to_csv("monotonically increasing only reactions lactose.csv")
d9.to_csv("increasing and decreasing and stable reactions lactose.csv")
d10.to_csv("increasing and decreasing only reactions lactose.csv")

# %%
d11= pd.DataFrame (csvFile2, columns = ['Biomass'])
d11.to_csv("csvFile2.csv")

# %%
len(a.reactions)
# Out:
# 2726
